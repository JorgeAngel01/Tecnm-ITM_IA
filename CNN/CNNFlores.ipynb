# %%
import cv2 

img = cv2.imread('../../a/flowers/black_eyed_susan/1007595613_b884ca8509_c.jpg')
""" img = cv2.imread('/home/angel/Desktop/IA/sportimages/basket/basket_0004.jpg') """

print(img.shape[0], img.shape[1], img.shape[2], len(img.shape))
# Out:
# 256 256 3 3

# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# # Importar Librerías

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from skimage.transform import resize
from skimage import img_as_ubyte

# %%
import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
#from keras.layers import Conv2D, MaxPooling2D
#from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, Conv2D
)
from keras.layers import LeakyReLU
# Out:
# WARNING:tensorflow:From c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Cargar set de Imágenes

# %%
dirname = os.path.join(os.getcwd(),'../../dataAugmented/')
""" dirname = os.path.join(os.getcwd(),'/home/likcos/DataSets/sportimages/sportimages') """
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

small_size = (64, 64, 3)  # Adjust the size as needed

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            if(len(image.shape)==3):
                resized_image = resize(image, small_size)
                resized_image = img_as_ubyte(resized_image)
                images.append(resized_image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if len(image.shape) == 2:
                # Grayscale image - delete the file
                print(f"Deleting: {filepath} - Grayscale image")
                os.remove(filepath)
            # Deleted all non RGB images
            
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# leyendo imagenes de  c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\CNN\../../dataAugmented/\
# c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\CNN\../../dataAugmented/\astilbe 1
# c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\CNN\../../dataAugmented/\black_eyed_susan 12580
# c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\CNN\../../dataAugmented/\common_daisy 14911
# c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\CNN\../../dataAugmented/\iris 11755
# c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\CNN\../../dataAugmented/\paradisebirds 15577
# Directorios leidos: 5
# Imagenes en cada directorio [12581, 14911, 11755, 15577, 19437]
# suma Total de imagenes en subdirs: 74261

# %% [markdown]
# # Creamos las etiquetas

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  74261

# %%
flores=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    flores.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 astilbe
# 1 black_eyed_susan
# 2 common_daisy
# 3 iris
# 4 paradisebirds

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy



# Find the unique numbers from the train labels
classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# # Creamos Sets de Entrenamiento y Test

# %%
print('Shape of X:', X.shape)
print('Shape of y:', y.shape)
print(len(images))
# Out:
# Shape of X: (74261, 64, 64, 3)
# Shape of y: (74261,)
# 74261

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (59408, 64, 64, 3) (59408,)
# Testing data shape :  (14853, 64, 64, 3) (14853,)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Display the first image in testing data
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 1')

# %% [markdown]
# # Preprocesamos las imagenes

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X/255.
test_X = test_X/255.
plt.imshow(test_X[0,:,:])

# %% [markdown]
# ## Hacemos el One-hot Encoding para la red

# %%
# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Display the change for category label using one-hot encoding
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 2
# After conversion to one-hot: [0. 0. 1. 0. 0.]

# %% [markdown]
# # Creamos el Set de Entrenamiento y Validación

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (47526, 64, 64, 3) (11882, 64, 64, 3) (47526, 5) (11882, 5)

# %% [markdown]
# # Creamos el modelo de CNN

# %%
#declaramos variables con los parámetros de configuración de la red
""" INIT_LR = 1e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001 """
INIT_LR = 0.003 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 80 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 16 # cantidad de imágenes que se toman a la vez en memoria

# %%
flor_model = Sequential()
flor_model.add(Conv2D(32, kernel_size=(3, 3),activation='linear',padding='same',input_shape=(64,64,3)))
flor_model.add(LeakyReLU(alpha=0.1))
flor_model.add(MaxPooling2D((2, 2),padding='same'))
flor_model.add(Dropout(0.5))
""" 
flor_model.add(Conv2D(64, kernel_size=(3, 3), activation='linear', padding='same'))
flor_model.add(LeakyReLU(alpha=0.1))
flor_model.add(MaxPooling2D((2, 2), padding='same'))
flor_model.add(Dropout(0.5)) """

flor_model.add(Flatten())
flor_model.add(Dense(32, activation='linear'))
flor_model.add(LeakyReLU(alpha=0.1))
flor_model.add(Dropout(0.5))
flor_model.add(Dense(nClasses, activation='softmax'))
# Out:
# WARNING:tensorflow:From c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\venv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
flor_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 64, 64, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 32)                1048608
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 1049669 (4.00 MB)
# Trainable params: 1049669 (4.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
flor_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])

# %% [markdown]
# # Entrenamos el modelo: Aprende a clasificar imágenes

# %%
# este paso puede tomar varios minutos, dependiendo de tu ordenador, cpu y memoria ram libre
flor_train = flor_model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))
# Out:
# Epoch 1/80
# WARNING:tensorflow:From c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\jorge\Desktop\Tec\9no Sem\Tecnm-ITM_IA\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2971/2971 [==============================] - 26s 9ms/step - loss: 0.9717 - accuracy: 0.6296 - val_loss: 0.6931 - val_accuracy: 0.7575
# Epoch 2/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.6907 - accuracy: 0.7539 - val_loss: 0.5379 - val_accuracy: 0.8158
# Epoch 3/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.5650 - accuracy: 0.8047 - val_loss: 0.4234 - val_accuracy: 0.8609
# Epoch 4/80
# 2971/2971 [==============================] - 25s 9ms/step - loss: 0.4959 - accuracy: 0.8308 - val_loss: 0.3683 - val_accuracy: 0.8814
# Epoch 5/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.4524 - accuracy: 0.8486 - val_loss: 0.3479 - val_accuracy: 0.8802
# Epoch 6/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.4258 - accuracy: 0.8553 - val_loss: 0.3173 - val_accuracy: 0.8977
# Epoch 7/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.4089 - accuracy: 0.8623 - val_loss: 0.3061 - val_accuracy: 0.9006
# Epoch 8/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3892 - accuracy: 0.8698 - val_loss: 0.2886 - val_accuracy: 0.9014
# Epoch 9/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3746 - accuracy: 0.8729 - val_loss: 0.3007 - val_accuracy: 0.8950
# Epoch 10/80
# 2971/2971 [==============================] - 25s 9ms/step - loss: 0.3655 - accuracy: 0.8756 - val_loss: 0.2700 - val_accuracy: 0.9137
# Epoch 11/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.3549 - accuracy: 0.8811 - val_loss: 0.2710 - val_accuracy: 0.9092
# Epoch 12/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3447 - accuracy: 0.8845 - val_loss: 0.2524 - val_accuracy: 0.9150
# Epoch 13/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3373 - accuracy: 0.8850 - val_loss: 0.2476 - val_accuracy: 0.9187
# Epoch 14/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3327 - accuracy: 0.8856 - val_loss: 0.2406 - val_accuracy: 0.9176
# Epoch 15/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3294 - accuracy: 0.8877 - val_loss: 0.2365 - val_accuracy: 0.9224
# Epoch 16/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3168 - accuracy: 0.8934 - val_loss: 0.2417 - val_accuracy: 0.9159
# Epoch 17/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3153 - accuracy: 0.8941 - val_loss: 0.2352 - val_accuracy: 0.9233
# Epoch 18/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3081 - accuracy: 0.8948 - val_loss: 0.2258 - val_accuracy: 0.9231
# Epoch 19/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3065 - accuracy: 0.8959 - val_loss: 0.2266 - val_accuracy: 0.9225
# Epoch 20/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3027 - accuracy: 0.8969 - val_loss: 0.2231 - val_accuracy: 0.9268
# Epoch 21/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.3005 - accuracy: 0.8976 - val_loss: 0.3067 - val_accuracy: 0.8905
# Epoch 22/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2943 - accuracy: 0.9012 - val_loss: 0.2226 - val_accuracy: 0.9223
# Epoch 23/80
# 2971/2971 [==============================] - 23s 8ms/step - loss: 0.2934 - accuracy: 0.8992 - val_loss: 0.2197 - val_accuracy: 0.9262
# Epoch 24/80
# 2971/2971 [==============================] - 23s 8ms/step - loss: 0.2879 - accuracy: 0.9013 - val_loss: 0.2149 - val_accuracy: 0.9264
# Epoch 25/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2834 - accuracy: 0.9034 - val_loss: 0.2100 - val_accuracy: 0.9298
# Epoch 26/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2841 - accuracy: 0.9031 - val_loss: 0.2087 - val_accuracy: 0.9296
# Epoch 27/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2784 - accuracy: 0.9050 - val_loss: 0.2119 - val_accuracy: 0.9286
# Epoch 28/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2765 - accuracy: 0.9056 - val_loss: 0.2044 - val_accuracy: 0.9312
# Epoch 29/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2755 - accuracy: 0.9061 - val_loss: 0.2076 - val_accuracy: 0.9277
# Epoch 30/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2726 - accuracy: 0.9064 - val_loss: 0.2035 - val_accuracy: 0.9321
# Epoch 31/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2693 - accuracy: 0.9079 - val_loss: 0.2022 - val_accuracy: 0.9328
# Epoch 32/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2635 - accuracy: 0.9104 - val_loss: 0.1987 - val_accuracy: 0.9324
# Epoch 33/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2639 - accuracy: 0.9096 - val_loss: 0.2063 - val_accuracy: 0.9291
# Epoch 34/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2642 - accuracy: 0.9098 - val_loss: 0.2006 - val_accuracy: 0.9324
# Epoch 35/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2588 - accuracy: 0.9114 - val_loss: 0.2097 - val_accuracy: 0.9278
# Epoch 36/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2577 - accuracy: 0.9116 - val_loss: 0.1948 - val_accuracy: 0.9347
# Epoch 37/80
# 2971/2971 [==============================] - 26s 9ms/step - loss: 0.2556 - accuracy: 0.9125 - val_loss: 0.1942 - val_accuracy: 0.9344
# Epoch 38/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2553 - accuracy: 0.9128 - val_loss: 0.1946 - val_accuracy: 0.9345
# Epoch 39/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2541 - accuracy: 0.9115 - val_loss: 0.1922 - val_accuracy: 0.9357
# Epoch 40/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2511 - accuracy: 0.9132 - val_loss: 0.1908 - val_accuracy: 0.9354
# Epoch 41/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2502 - accuracy: 0.9143 - val_loss: 0.1876 - val_accuracy: 0.9384
# Epoch 42/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2495 - accuracy: 0.9138 - val_loss: 0.1858 - val_accuracy: 0.9387
# Epoch 43/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2469 - accuracy: 0.9150 - val_loss: 0.1868 - val_accuracy: 0.9370
# Epoch 44/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2424 - accuracy: 0.9172 - val_loss: 0.1858 - val_accuracy: 0.9358
# Epoch 45/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2426 - accuracy: 0.9168 - val_loss: 0.1816 - val_accuracy: 0.9400
# Epoch 46/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2401 - accuracy: 0.9175 - val_loss: 0.1836 - val_accuracy: 0.9373
# Epoch 47/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2389 - accuracy: 0.9177 - val_loss: 0.1873 - val_accuracy: 0.9366
# Epoch 48/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2406 - accuracy: 0.9178 - val_loss: 0.1780 - val_accuracy: 0.9401
# Epoch 49/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2380 - accuracy: 0.9184 - val_loss: 0.1793 - val_accuracy: 0.9404
# Epoch 50/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2352 - accuracy: 0.9182 - val_loss: 0.1766 - val_accuracy: 0.9402
# Epoch 51/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2342 - accuracy: 0.9209 - val_loss: 0.1812 - val_accuracy: 0.9392
# Epoch 52/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2334 - accuracy: 0.9199 - val_loss: 0.1785 - val_accuracy: 0.9402
# Epoch 53/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2306 - accuracy: 0.9214 - val_loss: 0.1763 - val_accuracy: 0.9407
# Epoch 54/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2276 - accuracy: 0.9212 - val_loss: 0.1748 - val_accuracy: 0.9416
# Epoch 55/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2271 - accuracy: 0.9219 - val_loss: 0.1752 - val_accuracy: 0.9402
# Epoch 56/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2283 - accuracy: 0.9210 - val_loss: 0.1740 - val_accuracy: 0.9416
# Epoch 57/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2263 - accuracy: 0.9214 - val_loss: 0.1724 - val_accuracy: 0.9423
# Epoch 58/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2272 - accuracy: 0.9217 - val_loss: 0.1728 - val_accuracy: 0.9433
# Epoch 59/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2227 - accuracy: 0.9239 - val_loss: 0.1714 - val_accuracy: 0.9442
# Epoch 60/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2263 - accuracy: 0.9227 - val_loss: 0.1697 - val_accuracy: 0.9438
# Epoch 61/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2216 - accuracy: 0.9232 - val_loss: 0.1725 - val_accuracy: 0.9434
# Epoch 62/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2196 - accuracy: 0.9246 - val_loss: 0.1711 - val_accuracy: 0.9425
# Epoch 63/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2192 - accuracy: 0.9247 - val_loss: 0.1685 - val_accuracy: 0.9436
# Epoch 64/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2193 - accuracy: 0.9255 - val_loss: 0.1675 - val_accuracy: 0.9439
# Epoch 65/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2169 - accuracy: 0.9251 - val_loss: 0.1661 - val_accuracy: 0.9447
# Epoch 66/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2171 - accuracy: 0.9245 - val_loss: 0.1662 - val_accuracy: 0.9444
# Epoch 67/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2163 - accuracy: 0.9260 - val_loss: 0.1660 - val_accuracy: 0.9439
# Epoch 68/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2187 - accuracy: 0.9256 - val_loss: 0.1775 - val_accuracy: 0.9384
# Epoch 69/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2149 - accuracy: 0.9254 - val_loss: 0.1646 - val_accuracy: 0.9460
# Epoch 70/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2136 - accuracy: 0.9253 - val_loss: 0.1640 - val_accuracy: 0.9452
# Epoch 71/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2116 - accuracy: 0.9259 - val_loss: 0.1656 - val_accuracy: 0.9451
# Epoch 72/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2102 - accuracy: 0.9269 - val_loss: 0.1649 - val_accuracy: 0.9443
# Epoch 73/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2108 - accuracy: 0.9274 - val_loss: 0.1621 - val_accuracy: 0.9445
# Epoch 74/80
# 2971/2971 [==============================] - 24s 8ms/step - loss: 0.2095 - accuracy: 0.9262 - val_loss: 0.1617 - val_accuracy: 0.9465
# Epoch 75/80
# 2971/2971 [==============================] - 25s 8ms/step - loss: 0.2076 - accuracy: 0.9286 - val_loss: 0.1597 - val_accuracy: 0.9465
# Epoch 76/80
# 2971/2971 [==============================] - 26s 9ms/step - loss: 0.2091 - accuracy: 0.9284 - val_loss: 0.1722 - val_accuracy: 0.9395
# Epoch 77/80
# 2971/2971 [==============================] - 26s 9ms/step - loss: 0.2102 - accuracy: 0.9273 - val_loss: 0.1607 - val_accuracy: 0.9455
# Epoch 78/80
# 2971/2971 [==============================] - 26s 9ms/step - loss: 0.2023 - accuracy: 0.9307 - val_loss: 0.1592 - val_accuracy: 0.9461
# Epoch 79/80
# 2971/2971 [==============================] - 25s 9ms/step - loss: 0.2044 - accuracy: 0.9285 - val_loss: 0.1577 - val_accuracy: 0.9463
# Epoch 80/80
# 2971/2971 [==============================] - 25s 9ms/step - loss: 0.2034 - accuracy: 0.9300 - val_loss: 0.1613 - val_accuracy: 0.9446

# %%
# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
""" flor_model.save("/home/likcos/setDocto/celulas.h5") """
flor_model.save("./flor_model5.h5py")
# Out:
# INFO:tensorflow:Assets written to: ./flor_model5.h5py\assets
# INFO:tensorflow:Assets written to: ./flor_model5.h5py\assets

# %% [markdown]
# # Evaluamos la red

# %%
test_eval = flor_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 465/465 [==============================] - 2s 3ms/step - loss: 0.1603 - accuracy: 0.9460

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.16031350195407867
# Test accuracy: 0.9460041522979736

# %%
flor_train.history
# Out:
# {'loss': [0.9717342853546143,
#   0.6907315254211426,
#   0.5650436282157898,
#   0.4959312677383423,
#   0.45242705941200256,
#   0.42575085163116455,
#   0.408858060836792,
#   0.3891947865486145,
#   0.37460264563560486,
#   0.3654853105545044,
#   0.35492920875549316,
#   0.34474167227745056,
#   0.3372648060321808,
#   0.33271360397338867,
#   0.32940325140953064,
#   0.31675446033477783,
#   0.315266877412796,
#   0.30807924270629883,
#   0.30647730827331543,
#   0.3027401566505432,
#   0.3004850447177887,
#   0.29429420828819275,
#   0.2933531701564789,
#   0.2878870368003845,
#   0.2834014892578125,
#   0.28414538502693176,
#   0.2784140408039093,
#   0.2765143811702728,
#   0.2755277156829834,
#   0.2725940942764282,
#   0.26929113268852234,
#   0.2634868621826172,
#   0.26387497782707214,
#   0.2642149031162262,
#   0.25875362753868103,
#   0.25771665573120117,
#   0.2556069493293762,
#   0.2552565932273865,
#   0.2541428506374359,
#   0.25107717514038086,
#   0.2501890957355499,
#   0.24952930212020874,
#   0.246880441904068,
#   0.24236710369586945,
#   0.24257878959178925,
#   0.24010002613067627,
#   0.23887315392494202,
#   0.240598663687706,
#   0.2379763424396515,
#   0.2352159321308136,
#   0.23424172401428223,
#   0.23337575793266296,
#   0.23055459558963776,
#   0.22759747505187988,
#   0.22705240547657013,
#   0.22828561067581177,
#   0.22632412612438202,
#   0.22723133862018585,
#   0.22266821563243866,
#   0.22625049948692322,
#   0.22158214449882507,
#   0.21960845589637756,
#   0.21921825408935547,
#   0.21927571296691895,
#   0.21688808500766754,
#   0.21705195307731628,
#   0.21634161472320557,
#   0.21866318583488464,
#   0.2148708701133728,
#   0.21356116235256195,
#   0.21164825558662415,
#   0.21018345654010773,
#   0.210796520113945,
#   0.2094881236553192,
#   0.20759114623069763,
#   0.20907177031040192,
#   0.21021601557731628,
#   0.20228202641010284,
#   0.20441019535064697,
#   0.2034476399421692],
#  'accuracy': [0.6296132802963257,
#   0.7538610696792603,
#   0.8047174215316772,
#   0.8307663202285767,
#   0.8485671281814575,
#   0.8552792072296143,
#   0.8623069524765015,
#   0.8698186278343201,
#   0.8729116916656494,
#   0.8756470084190369,
#   0.8810756206512451,
#   0.8845053315162659,
#   0.885010302066803,
#   0.8855994343757629,
#   0.8876615166664124,
#   0.8933636546134949,
#   0.8941000699996948,
#   0.8947944045066833,
#   0.8958675265312195,
#   0.8968775272369385,
#   0.8975929021835327,
#   0.9012119770050049,
#   0.8991920351982117,
#   0.9013382196426392,
#   0.9033792018890381,
#   0.9031056761741638,
#   0.9050414562225342,
#   0.9056095480918884,
#   0.906135618686676,
#   0.906430184841156,
#   0.9079450964927673,
#   0.9103648662567139,
#   0.909565269947052,
#   0.9098387956619263,
#   0.9113537669181824,
#   0.9116062521934509,
#   0.9125110507011414,
#   0.9128476977348328,
#   0.9115010499954224,
#   0.9131843447685242,
#   0.9143416285514832,
#   0.9138156175613403,
#   0.9149518013000488,
#   0.9171611070632935,
#   0.9167823791503906,
#   0.9174978137016296,
#   0.9176661372184753,
#   0.917834460735321,
#   0.9183604717254639,
#   0.9181711077690125,
#   0.9209064245223999,
#   0.9198964834213257,
#   0.9213904142379761,
#   0.9212220907211304,
#   0.9218743443489075,
#   0.920969545841217,
#   0.9213693737983704,
#   0.9217060208320618,
#   0.9238522052764893,
#   0.9227370023727417,
#   0.9231789112091064,
#   0.9246096611022949,
#   0.9247148633003235,
#   0.9254513382911682,
#   0.9250515699386597,
#   0.9245044589042664,
#   0.925977349281311,
#   0.9256196618080139,
#   0.9254302978515625,
#   0.9253250956535339,
#   0.9259352684020996,
#   0.9268821477890015,
#   0.92742919921875,
#   0.9262298345565796,
#   0.9285654425621033,
#   0.9283970594406128,
#   0.92728191614151,
#   0.930690586566925,
#   0.9284602403640747,
#   0.9299961924552917],
#  'val_loss': [0.6930672526359558,
#   0.5379191637039185,
#   0.42341363430023193,
#   0.36829257011413574,
#   0.3479473292827606,
#   0.31730496883392334,
#   0.3060658872127533,
#   0.2885522246360779,
#   0.30067673325538635,
#   0.26998379826545715,
#   0.27101796865463257,
#   0.2523624300956726,
#   0.24763093888759613,
#   0.24060070514678955,
#   0.23651818931102753,
#   0.24166792631149292,
#   0.23522543907165527,
#   0.22582551836967468,
#   0.22664190828800201,
#   0.22310353815555573,
#   0.3066510558128357,
#   0.22259171307086945,
#   0.21967759728431702,
#   0.21493341028690338,
#   0.21000416576862335,
#   0.20871302485466003,
#   0.21193493902683258,
#   0.20443642139434814,
#   0.20758505165576935,
#   0.2034928947687149,
#   0.2022126019001007,
#   0.1986708641052246,
#   0.20625559985637665,
#   0.20063604414463043,
#   0.2096923440694809,
#   0.19479742646217346,
#   0.19422416388988495,
#   0.19455893337726593,
#   0.1921800971031189,
#   0.19079211354255676,
#   0.18756669759750366,
#   0.1857547014951706,
#   0.18679383397102356,
#   0.18582741916179657,
#   0.18157702684402466,
#   0.1836148351430893,
#   0.18727324903011322,
#   0.17798946797847748,
#   0.17925991117954254,
#   0.17657187581062317,
#   0.1812450885772705,
#   0.1784609854221344,
#   0.17629474401474,
#   0.17478995025157928,
#   0.17515651881694794,
#   0.1739911288022995,
#   0.17235292494297028,
#   0.17284934222698212,
#   0.1714288294315338,
#   0.16971427202224731,
#   0.172472283244133,
#   0.1711185723543167,
#   0.16848613321781158,
#   0.16748017072677612,
#   0.16608771681785583,
#   0.16617733240127563,
#   0.16603678464889526,
#   0.17748980224132538,
#   0.164606511592865,
#   0.16402976214885712,
#   0.1655651181936264,
#   0.16488653421401978,
#   0.16208790242671967,
#   0.16173426806926727,
#   0.1597362756729126,
#   0.17222395539283752,
#   0.16074009239673615,
#   0.1591864973306656,
#   0.15772490203380585,
#   0.16126525402069092],
#  'val_accuracy': [0.7575324177742004,
#   0.815771758556366,
#   0.8608819842338562,
#   0.8814172744750977,
#   0.8801548480987549,
#   0.8976603150367737,
#   0.9006059765815735,
#   0.9013634324073792,
#   0.8949671983718872,
#   0.9136509299278259,
#   0.9091903567314148,
#   0.9149974584579468,
#   0.9187005758285522,
#   0.9176064729690552,
#   0.9224036335945129,
#   0.9159232378005981,
#   0.9233294129371643,
#   0.9230769276618958,
#   0.9224877953529358,
#   0.9267799854278564,
#   0.8905066251754761,
#   0.9223194718360901,
#   0.9261908531188965,
#   0.9263591766357422,
#   0.9298098087310791,
#   0.9295573234558105,
#   0.9286315441131592,
#   0.9311563968658447,
#   0.9277057647705078,
#   0.9320821166038513,
#   0.932839572429657,
#   0.9324187636375427,
#   0.9290523529052734,
#   0.9324187636375427,
#   0.9277899265289307,
#   0.9346911311149597,
#   0.9343544840812683,
#   0.934522807598114,
#   0.9357010722160339,
#   0.9353644251823425,
#   0.9383941888809204,
#   0.9387308359146118,
#   0.9370476603507996,
#   0.9357852339744568,
#   0.9399932622909546,
#   0.9373001456260681,
#   0.9366268515586853,
#   0.9400774240493774,
#   0.9404140710830688,
#   0.9402457475662231,
#   0.9391516447067261,
#   0.9402457475662231,
#   0.9406665563583374,
#   0.9415923357009888,
#   0.9401615858078003,
#   0.9415923357009888,
#   0.9423497915267944,
#   0.9432755708694458,
#   0.9442012906074524,
#   0.9437804818153381,
#   0.9433597326278687,
#   0.9425181150436401,
#   0.9436121582984924,
#   0.9439488053321838,
#   0.9447062611579895,
#   0.9443696141242981,
#   0.9439488053321838,
#   0.9383941888809204,
#   0.9459686875343323,
#   0.9452112317085266,
#   0.9451270699501038,
#   0.9442854523658752,
#   0.944453775882721,
#   0.9464736580848694,
#   0.9464736580848694,
#   0.9394882917404175,
#   0.945547878742218,
#   0.946137011051178,
#   0.9463053345680237,
#   0.9446220993995667]}

# %%
accuracy = flor_train.history['accuracy']
val_accuracy = flor_train.history['val_accuracy']
loss = flor_train.history['loss']
val_loss = flor_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes2 = flor_model.predict(test_X)
# Out:
# 465/465 [==============================] - 1s 3ms/step

# %%
predicted_classes=[]
for predicted_sport in predicted_classes2:
    predicted_classes.append(predicted_sport.tolist().index(max(predicted_sport)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((14853,), (14853,))

# %% [markdown]
# # Aprendamos de los errores: Qué mejorar

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(64,64,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(flores[predicted_classes[correct]],
                                                    flores[test_Y[correct]]))

    plt.tight_layout()
# Out:
# Found 14051 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(64,64,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(flores[predicted_classes[incorrect]],
                                                    flores[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 802 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.88      0.93      0.91      2559
#      Class 1       0.98      0.98      0.98      2948
#      Class 2       0.92      0.89      0.91      2294
#      Class 3       0.95      0.91      0.93      3120
#      Class 4       0.97      0.99      0.98      3932
#
#     accuracy                           0.95     14853
#    macro avg       0.94      0.94      0.94     14853
# weighted avg       0.95      0.95      0.95     14853
